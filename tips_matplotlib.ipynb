# %%
pip install camply
# Out:
# Collecting camply
#   Downloading camply-0.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: requests in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (2.27.1)
# Requirement already satisfied: PyYAML in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (6.0)
# Requirement already satisfied: pandas in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (1.4.1)
# Collecting python-dotenv
#   Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: tenacity in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (8.0.1)
# Requirement already satisfied: pytz in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (2021.3)
# Requirement already satisfied: pydantic in ./opt/anaconda3/lib/python3.9/site-packages (from camply) (1.8.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas->camply) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in ./opt/anaconda3/lib/python3.9/site-packages (from pandas->camply) (1.21.2)
# Requirement already satisfied: six>=1.5 in ./opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->camply) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./opt/anaconda3/lib/python3.9/site-packages (from pydantic->camply) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->camply) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->camply) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->camply) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./opt/anaconda3/lib/python3.9/site-packages (from requests->camply) (2.0.4)
# Installing collected packages: python-dotenv, camply
# Successfully installed camply-0.3.0 python-dotenv-0.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
from camply.containers import SearchWindow
from camply.search import SearchRecreationDotGov

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue='day', size='size', palette='YlGnBu')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'], kde=True, bins=15)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.distplot(tips['tip'], kde=True, bins=15)
# Out:
# /Users/apichet/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.barplot(x='sex', y='tip', data=tips, palette='YlGnBu')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxenplot(x='day', y='total_bill', data=tips, hue='sex', palette='YlGnBu')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='reg')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True, cmap='YlGnBu')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hex', cmap='YlGnBu')
